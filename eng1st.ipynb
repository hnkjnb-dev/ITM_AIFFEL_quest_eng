# %% [markdown]
# <a href="https://colab.research.google.com/github/itmin2407/AIFFEL_quest_eng/blob/main/eng1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(1)
# Out:
# 1

# %%
print(2)
# Out:
# 2

# %%
print(3)
# Out:
# 3
